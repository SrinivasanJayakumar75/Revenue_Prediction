# %% [markdown]
# Importing the required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %% [markdown]
# Reading the DataSet

# %%
df = pd.read_csv('/content/marketing_data_1 - marketing_data_1.csv')

# %%
df
# Out:
#          ID  Year_Birth   Education Marital_Status      Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  $84,835.00        0
# 1         1        1961  Graduation         Single  $57,091.00        0
# 2     10476        1958  Graduation        Married  $67,267.00        0
# 3      1386        1967  Graduation       Together  $32,474.00        1
# 4      5371        1989  Graduation         Single  $21,474.00        1
# ...     ...         ...         ...            ...         ...      ...
# 2235  10142        1976         PhD       Divorced  $66,476.00        0
# 2236   5263        1977    2n Cycle        Married  $31,056.00        1
# 2237     22        1976  Graduation       Divorced  $46,310.00        1
# 2238    528        1978  Graduation        Married  $65,819.00        0
# 2239   4070        1969         PhD        Married  $94,871.00        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %% [markdown]
# Checking for Null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   object
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
df.isnull().any()
# Out:
# ID                     False
# Year_Birth             False
# Education              False
# Marital_Status         False
# Income                  True
# Kidhome                False
# Teenhome               False
# Dt_Customer            False
# Recency                False
# MntWines               False
# MntFruits              False
# MntMeatProducts        False
# MntFishProducts        False
# MntSweetProducts       False
# MntGoldProds           False
# NumDealsPurchases      False
# NumWebPurchases        False
# NumCatalogPurchases    False
# NumStorePurchases      False
# NumWebVisitsMonth      False
# AcceptedCmp3           False
# AcceptedCmp4           False
# AcceptedCmp5           False
# AcceptedCmp1           False
# AcceptedCmp2           False
# Response               False
# Complain               False
# Country                False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Response                0
# Complain                0
# Country                 0
# dtype: int64

# %% [markdown]
# Cleaning the data

# %%
df['Income'] = df['Income'].str.replace('$','')
# Out:
# <ipython-input-7-50142c2c5b53>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Income'] = df['Income'].str.replace('$','')

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# ID                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# AcceptedCmp3           0
# AcceptedCmp4           0
# AcceptedCmp5           0
# AcceptedCmp1           0
# AcceptedCmp2           0
# Response               0
# Complain               0
# Country                0
# dtype: int64

# %%
df.shape
# Out:
# (2216, 28)

# %%
df.describe()
# Out:
#                  ID   Year_Birth      Kidhome     Teenhome      Recency  \
# count   2216.000000  2216.000000  2216.000000  2216.000000  2216.000000
# mean    5588.353339  1968.820397     0.441787     0.505415    49.012635
# std     3249.376275    11.985554     0.536896     0.544181    28.948352
# min        0.000000  1893.000000     0.000000     0.000000     0.000000
# 25%     2814.750000  1959.000000     0.000000     0.000000    24.000000
# 50%     5458.500000  1970.000000     0.000000     0.000000    49.000000
# 75%     8421.750000  1977.000000     1.000000     1.000000    74.000000
# max    11191.000000  1996.000000     2.000000     2.000000    99.000000
#
#           MntWines    MntFruits  MntMeatProducts  MntFishProducts  \
# count  2216.000000  2216.000000      2216.000000      2216.000000
# mean    305.091606    26.356047       166.995939        37.637635
# std     337.327920    39.793917       224.283273        54.752082
# ...

# %%
df
# Out:
#          ID  Year_Birth   Education Marital_Status     Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84,835.00        0
# 1         1        1961  Graduation         Single  57,091.00        0
# 2     10476        1958  Graduation        Married  67,267.00        0
# 3      1386        1967  Graduation       Together  32,474.00        1
# 4      5371        1989  Graduation         Single  21,474.00        1
# ...     ...         ...         ...            ...        ...      ...
# 2235  10142        1976         PhD       Divorced  66,476.00        0
# 2236   5263        1977    2n Cycle        Married  31,056.00        1
# 2237     22        1976  Graduation       Divorced  46,310.00        1
# 2238    528        1978  Graduation        Married  65,819.00        0
# 2239   4070        1969         PhD        Married  94,871.00        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %%
df['Education'].unique()
# Out:
# array(['Graduation', 'PhD', '2n Cycle', 'Master', 'Basic'], dtype=object)

# %%
df['Marital_Status'].unique()
# Out:
# array(['Divorced', 'Single', 'Married', 'Together', 'Widow', 'YOLO',
#        'Alone', 'Absurd'], dtype=object)

# %% [markdown]
# Label encoding the columns

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Education'] = le.fit_transform(df['Education'])

# %%
df['Education'].unique()
# Out:
# array([2, 4, 0, 3, 1])

# %%
df['Marital_Status'] = le.fit_transform(df['Marital_Status'])

# %%
df['Marital_Status'].unique()
# Out:
# array([2, 4, 3, 5, 6, 7, 1, 0])

# %%
df['Dt_Customer'] = pd.to_datetime(df['Dt_Customer'])

# %%
df['Dt_Customer'] = df['Dt_Customer'].astype('category').cat.codes

# %%
df['Country'] = le.fit_transform(df['Country'])

# %%
df
# Out:
#          ID  Year_Birth  Education  Marital_Status     Income  Kidhome  \
# 0      1826        1970          2               2  84,835.00        0
# 1         1        1961          2               4  57,091.00        0
# 2     10476        1958          2               3  67,267.00        0
# 3      1386        1967          2               5  32,474.00        1
# 4      5371        1989          2               4  21,474.00        1
# ...     ...         ...        ...             ...        ...      ...
# 2235  10142        1976          4               2  66,476.00        0
# 2236   5263        1977          0               3  31,056.00        1
# 2237     22        1976          2               2  46,310.00        1
# 2238    528        1978          2               3  65,819.00        0
# 2239   4070        1969          4               3  94,871.00        0
#
#       Teenhome  Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %% [markdown]
# Visual Analysis

# %%
#Multivariate analysis
plt.figure(figsize=(20,7))
sns.heatmap(df.corr(), annot=True)
# Out:
# <ipython-input-23-c220b6daf3bf>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)
# <Axes: >

# %%
df['Income'] = df['Income'].str.replace(',', '')

# %% [markdown]
# Appliying PCA

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.decomposition import PCA
selected_features = df.iloc[:, :28]
pca = PCA(n_components=15)
principal_components = pca.fit_transform(selected_features)
loadings = pca.components_[0]
loading_df = pd.DataFrame({'Feature': selected_features.columns, 'Loading': loadings})

loading_df['Abs_Loading'] = loading_df['Loading'].abs()
loading_df = loading_df.sort_values(by='Abs_Loading', ascending=False)

print(loading_df)
# Out:
#                 Feature       Loading   Abs_Loading
# 4                Income  9.999537e-01  9.999537e-01
# 9              MntWines  7.754741e-03  7.754741e-03
# 11      MntMeatProducts  5.209108e-03  5.209108e-03
# 0                    ID  1.718453e-03  1.718453e-03
# 12      MntFishProducts  9.545686e-04  9.545686e-04
# 13     MntSweetProducts  7.191218e-04  7.191218e-04
# 10            MntFruits  6.810972e-04  6.810972e-04
# 14         MntGoldProds  6.708816e-04  6.708816e-04
# 7           Dt_Customer  1.412592e-04  1.412592e-04
# 1            Year_Birth -7.703091e-05  7.703091e-05
# 17  NumCatalogPurchases  6.850102e-05  6.850102e-05
# 18    NumStorePurchases  6.836238e-05  6.836238e-05
# 19    NumWebVisitsMonth -5.328720e-05  5.328720e-05
# 16      NumWebPurchases  4.223547e-05  4.223547e-05
# 5               Kidhome -9.143040e-06  9.143040e-06
# 15    NumDealsPurchases -6.350758e-06  6.350758e-06
# 2             Education  5.389888e-06  5.389888e-06
# ...

# %% [markdown]
# Creating dataframe after PCA

# %%
useful_cols = ['NumDealsPurchases', 'Education', 'Kidhome', 'NumWebPurchases', 'NumWebVisitsMonth', 'Year_Birth', 'Dt_Customer','MntGoldProds', 'MntFruits', 'MntSweetProducts', 'ID', 'MntMeatProducts', 'Income', 'MntWines']

# %%
df = df[useful_cols]

# %%
df.shape
# Out:
# (2216, 14)

# %%
df
# Out:
#       NumDealsPurchases  Education  Kidhome  NumWebPurchases  \
# 0                     1          2        0                4
# 1                     1          2        0                7
# 2                     1          2        0                3
# 3                     1          2        1                1
# 4                     2          2        1                3
# ...                 ...        ...      ...              ...
# 2235                  2          4        0                5
# 2236                  1          0        1                1
# 2237                  2          2        1                6
# 2238                  1          2        0                5
# 2239                  1          4        0                8
#
#       NumWebVisitsMonth  Year_Birth  Dt_Customer  MntGoldProds  MntFruits  \
# 0                     1        1970          648           218        104
# 1                     5        1961          647            37          5
# ...

# %%
df.describe()
# Out:
#        NumDealsPurchases    Education      Kidhome  NumWebPurchases  \
# count        2216.000000  2216.000000  2216.000000      2216.000000
# mean            2.323556     2.393953     0.441787         4.085289
# std             1.923716     1.124141     0.536896         2.740951
# min             0.000000     0.000000     0.000000         0.000000
# 25%             1.000000     2.000000     0.000000         2.000000
# 50%             2.000000     2.000000     0.000000         4.000000
# 75%             3.000000     3.000000     1.000000         6.000000
# max            15.000000     4.000000     2.000000        27.000000
#
#        NumWebVisitsMonth   Year_Birth  Dt_Customer  MntGoldProds    MntFruits  \
# count        2216.000000  2216.000000  2216.000000   2216.000000  2216.000000
# mean            5.319043  1968.820397   328.078971     43.965253    26.356047
# std             2.425359    11.985554   191.263667     51.815414    39.793917
# ...

# %% [markdown]
# Splitting the data into train test

# %%
X = df.iloc[:,:-1].values
Y = df.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state = 1, test_size = 0.3)

# %% [markdown]
# Model Building

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, model.predict(x_test))

# %%
mse
# Out:
# 39013.288754610796

# %%
from sklearn.tree import DecisionTreeRegressor
model2 = DecisionTreeRegressor()
model2.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
mse2 = mean_squared_error(y_test, model2.predict(x_test))
mse2
# Out:
# 55474.306766917296

# %%
from sklearn.svm import LinearSVR
model3 = LinearSVR()
model3.fit(x_train, y_train)
# Out:
# LinearSVR()

# %%
mse3 = mean_squared_error(y_test, model3.predict(x_test))
mse3
# Out:
# 51358.89767990961

# %%
from sklearn.linear_model import Lasso
model4 = Lasso()
model4.fit(x_train, y_train)
# Out:
# Lasso()

# %%
mse4 = mean_squared_error(y_test, model4.predict(x_test))
mse4
# Out:
# 39049.033175894685

# %%
from sklearn.linear_model import Ridge
model5 = Ridge()
model5.fit(x_train, y_train)
# Out:
# Ridge()

# %%
mse5 = mean_squared_error(y_test, model.predict(x_test))
mse5
# Out:
# 39013.288754610796

# %% [markdown]
# Comparing models

# %%
mses = [['LinearRegression', mse],
        ['DecisionTreeRegressor', mse2], ['LinearSVR', mse3],
        ['LassoRegression', mse4], ['RidgeRegression', mse5]]

RevenuePrediction = pd.DataFrame(mses, columns = ['RegressionModels', 'MeanSquaredError'])
RevenuePrediction
# Out:
#         RegressionModels  MeanSquaredError
# 0       LinearRegression      39013.288755
# 1  DecisionTreeRegressor      55474.306767
# 2              LinearSVR      51358.897680
# 3        LassoRegression      39049.033176
# 4        RidgeRegression      39013.288755

# %% [markdown]
# Saving the model

# %%
import pickle
pickle.dump(model, open('revenuemodel.pkl', 'wb'))
